# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df= pd.read_csv('geotracker-redone.csv',  encoding='ISO-8859-1')
df
# Out:
#        Unnamed: 0     GLOBAL_ID  \
# 0               0  DOD100186700
# 1               1  T10000012752
# 2               2  NPD100051582
# 3               3   T0604762455
# 4               4  T10000006370
# ...           ...           ...
# 75058       75058  SLT5S0753116
# 75059       75059  DOD100037100
# 75060       75060   T0604500317
# 75061       75061  T10000000477
# 75062       75062  T06019765361
#
#                                            BUSINESS_NAME STREET_NUMBER  \
# 0      Fort Hunter Liggett - Fort Hunter Liggett - LA...           NaN
# 1                                              McPhail's           975
# 2                                   San Luis Obispo WWTP            35
# 3                                  SMOTHERS DELUXE SHELL            55
# 4                                   One Lawrence Station          3305
# ...                                                  ...           ...
# 75058  CHEVRON PIPELINE CO - FORMER STANDARD OIL PIPE...           NaN
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
